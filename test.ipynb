# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import json

# %%
geo=gpd.read_file("data/geodata3.shp")

# %%
fig,ax=plt.subplots(1,1, figsize=(30,20))
geo.plot(ax=ax,column="radiation", cmap="Reds", legend=True)
plt.title("Globalstrahlung in Deutschland nach Landkreisen", size=15)
# Out:
# Text(0.5, 1.0, 'Globalstrahlung in Deutschland nach Landkreisen')
